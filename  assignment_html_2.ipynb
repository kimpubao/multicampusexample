# %%
'''
//001
    const x=12;
    if(x>10 && x<20)
        console.log(x)

    //002
    for(i=0; i<10; i++){
        if(i%2 == 0) {
            console.log(i);
        }
    }
    //003
    let str="";
    for(i=0; i<10;i++){
        if(i%2==0) str += i;
    }
    console.log(str);

    //004
    for(i=9; i>0;i--){
        if(i%2){
            console.log(i)
        }
    }

    //007
    let sum=0;
    for(let i=0;i<10;i++){
        sum +=1;
    }
    console.log(i)

    //008
    let sum = 0;
    for(let i = 1; i < 20; i++) {
        if(i % 2 != 0 && i % 3 != 0){
            s+=i;
        }
    }
    console.log(sum);

    //009
    let sum = 0;
    for (let i = 0; i < 20; i++) {
        if(i%2==0 || i%3==0){
            sum += i;
        }
    }
    console.log(sum);

    //010
    for(let i = 1; i<7; i++){
        for(let j =1; j<7;j++){
            if(i+j==6){
                console.log([i,j]);
            }
        }
    }
'''
